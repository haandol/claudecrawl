# %% [markdown]
# # Baseline Scraper
# - 웹페이지 주소를 입력해서 텍스트만 추출한다.

# %%
# !pip -q install -U requests playwright

# %%
# !playwright install

# %%
import os
import json

# web scraping
import requests
from playwright.async_api import async_playwright

from bs4 import BeautifulSoup

# %%
# 차단할 리소스 타입 정의
BLOCK_RESOURCE_TYPES = [
    'beacon',
    'csp_report', 
    'font',
    'image',
    'imageset',
    'media',
    'object',
    'texttrack',
]

# 차단할 트래커 및 광고 도메인 정의 
BLOCK_RESOURCE_NAMES = [
    'adzerk',
    'analytics',
    'cdn.api.twitter',
    'doubleclick',
    'exelator', 
    'facebook',
    'fontawesome',
    'google',
    'google-analytics',
    'googletagmanager',
    'adform',
]


async def intercept_route(route):
    """요청을 가로채서 차단된 리소스는 중단"""
    if route.request.resource_type in BLOCK_RESOURCE_TYPES:
        print(f'리소스 차단: {route.request.url} (타입: {route.request.resource_type})')
        return await route.abort()
    
    if any(tracker in route.request.url for tracker in BLOCK_RESOURCE_NAMES):
        print(f'트래커 차단: {route.request.url}')
        return await route.abort()
    
    return await route.continue_()

# %%
async def scrape(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        page = await context.new_page()
        await page.route("**/*", intercept_route)
        await page.goto(url)
        print(await page.content())
        await browser.close()

# %%
url = "https://lol.inven.co.kr/dataninfo/champion/manualTool.php?confirm=2"

# %%
await scrape(url)
# Out:
# 리소스 차단: https://upload3.inven.co.kr/upload/2023/08/18/bbs/i8268349154.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/cafe/common/btn_and01.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/cafe/common/btn_ios01.png (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2017/06/29/bbs/i16069371144.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2019/03/07/bbs/i13588389197.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2019/03/07/bbs/i14021823717.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2017/07/11/bbs/i15602285282.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2017/06/29/bbs/i14060662332.jpg (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2023/04/04/bbs/i8206687393.png (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2018/07/11/bbs/i14426205952.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Garen_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Galio_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gangplank_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gragas_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Graves_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gwen_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gnar_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nami_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nasus_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Naafiri_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nautilus_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nocturne_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nunu_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nidalee_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Neeko_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nilah_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Darius_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Diana_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Draven_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ryze_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Rakan_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Rammus_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Lux_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Rumble_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Renata%20Glasc_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Renekton_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Leona_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/RekSai_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Rell_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Rengar_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Lucian_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Lulu_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Leblanc_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/LeeSin_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Riven_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Lissandra_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/lillia_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/MasterYi_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Maokai_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Malzahar_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Malphite_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Mordekaiser_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Morgana_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/DrMundo_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/MissFortune_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Milio_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Bard_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Varus_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Vi_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Veigar_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Vayne_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Vex_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/BelVeth_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/VelKoz_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Volibear_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Braum_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Briar_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Brand_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Vladimir_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Blitzcrank_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Viego_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Viktor_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Poppy_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Samira_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Sion_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Sylas_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Shaco_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Senna_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Seraphine_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Sejuani_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/sett_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Sona_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Soraka_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Shen_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Shyvana_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Smolde_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Swain_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Skarner_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Sivir_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/XinZhao_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Syndra_Square_0_1+.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Singed_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Thresh_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ahri_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Amumu_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/AurelionSol_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ivern_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Azir_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Akali_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Akshan_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Aatrox_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Aphelios_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Alistar_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ambessa_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Annie_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Anivia_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ashe_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Yasuo_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ekko_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Elise_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/MonkeyKing_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Aurora_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/ornn_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Orianna_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Olaf_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Yone_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Yorick_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Udyr_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Urgot_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Warwick_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/yummi_square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Irelia_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Evelynn_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ezreal_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Illaoi_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/JarvanIV_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Xayah_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zyra_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zac_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Janna_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Jax_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zed_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Xerath_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zeri_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Jayce_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zoe_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Ziggs_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Jhin_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Zilean_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Jinx_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Chogath_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Karma_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Camille_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kassadin_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Karthus_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Cassiopeia_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/kaisa_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Khazix_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Katarina_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kalista_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kennen_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Caitlyn_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kayn_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kayle_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/KogMaw_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Corki_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Quinn_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/KSante_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kled_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Qiyana_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Kindred_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Taric_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Talon_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Taliyah_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/TahmKench_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Trundle_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Tristana_Square_0_4.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Tryndamere_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/TwistedFate_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Twitch_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Teemo_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Pyke_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Pantheon_Square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Fiddlesticks_Square_0_1_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Fiora_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Fizz_square_0_1.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Heimerdinger_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Hecarim_Square_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Hwei_Square_0.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/banner/banner_710x84_note1.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/icon_arrow_blue_2.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/fonticon/icon_34x15_confirm3.png (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/icon/none.gif (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2018/06/28/icon/i13435843704.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/icon_60x13_vote1.png (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2011/09/29/icon/i2986140133.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2016/12/24/icon/i15996998526.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2011/07/30/icon/i25425638.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2016/06/25/icon/i10578280204.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2012/05/24/icon/i1856400217.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2015/06/30/icon/i13112647352.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2013/11/27/icon/i4092888151.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2013/10/26/icon/i1234882318.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2014/11/26/icon/i2028815106.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2014/03/28/icon/i2561610130.gif (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2017/12/30/icon/i14216308137.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2018/03/26/icon/i14114346729.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2016/02/24/icon/i10971555667.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2012/04/29/icon/i1444599873.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2014/07/31/icon/i1961742099.jpg (타입: image)
# 리소스 차단: https://upload.inven.co.kr/upload/2013/04/24/icon/i2228964530.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2017/12/24/icon/i13596936458.jpg (타입: image)
# 리소스 차단: https://upload2.inven.co.kr/upload/2019/02/08/icon/i14437817266.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/banner/banner_710x90_novote1.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/banner/banner_710x150_manualtool1.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/webzine/s3/common/icon_rotate.png (타입: image)
# 리소스 차단: https://liveimg.afreecatv.com/m/279032460?1732597622 (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon01.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon02.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon05.png (타입: image)
# 트래커 차단: https://securepubads.g.doubleclick.net/tag/js/gpt.js
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/10/24/data/i1182019280.jpg (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/10/07/data/i1419401431.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/09/24/data/i1537177536.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/11/19/bbs/i1411136240.jpg (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/11/01/bbs/i1178476073.jpg (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/08/26/bbs/i1138301350.jpg (타입: image)
# 트래커 차단: https://www.googletagmanager.com/gtag/js?id=G-P0BBTC1DR3
# 트래커 차단: https://www.googletagmanager.com/gtm.js?id=GTM-PXPMBT3V
# 리소스 차단: https://static.inven.co.kr/image_2011/cafe/common/btn_and01.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/cafe/common/icon_app02.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/cafe/common/icon_mobile01.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/06/18/bbs/i1527859972.jpg (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/common/common/commu_img_sprite.png?v=210527a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bg_332x31_white1_menutitle.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bttn_70x23_viewall.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bttn_63x23_viewconfirm.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bttn_52x23_search_my_article.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bttn_54x23_gray1_search.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/bttn_63x23_red1_write.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/common/fonts/NotoSans-Medium.woff2 (타입: font)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Garen_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gragas_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Nasus_Square_0_2.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/site_image/lol/dataninfo/icon/champions/Gangplank_Square_0_3.jpg?v=240805a (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/sep_1x8_65a4af.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/lol/common/dot_4x1_404b5a.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2021/07/08/bbs/i21325716599.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2021/07/08/bbs/i21349766000.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2021/07/08/bbs/i21357196991.png (타입: image)
# 리소스 차단: https://upload3.inven.co.kr/upload/2024/09/13/bbs/i1880956573.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/webzine/s3/common/side_icon_all_b.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/common/footer_img_2022.png (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/common/fonts/NotoSans-Medium.woff (타입: font)
# /Users/dongkyl/.pyenv/versions/3.10.14/lib/python3.10/inspect.py:820: RuntimeWarning: coroutine 'scrape' was never awaited
#   if any(filename.endswith(s) for s in all_bytecode_suffixes):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 리소스 차단: https://gold.contentsfeed.com/lb/sd/nw?c=vis&id=b8c9e9af8214f8998dbf8d1bd30672d&lb_data=..._...&version=20231124 (타입: image)
# 리소스 차단: https://static.inven.co.kr/image_2011/common/common/bttn_18x17_white1_close.png (타입: image)
# 리소스 차단: https://ads.inven.co.kr/ad/202411/1122_DNF_C_950x60.jpg (타입: image)
# 리소스 차단: https://idm.skplanet.com/pixel?nid=17&uid=ca3e6dfdabb411efad390abed409cb62&url=%2F%2Fcdn.interworksmedia.co.kr%2Fempty.html&channel=web&debug=n (타입: image)
# 리소스 차단: https://ads.inven.co.kr/ad/202411/1121_MapleStory_PointA_UpperMiddle_800x144.jpg (타입: image)
# 리소스 차단: https://static.criteo.net/images/pixel.gif?ch=1 (타입: image)
# 리소스 차단: https://static.criteo.net/images/pixel.gif?ch=2 (타입: image)
# 리소스 차단: https://zicf.inven.co.kr/RealMedia/ads/Creatives/default/empty.gif (타입: image)
# 리소스 차단: https://ads.inven.co.kr/ad/202411/1118_Raven2_B_250x250.jpg (타입: image)
# 리소스 차단: https://data.adop.cc/collect.php?data=...%3D&aid=e0d2cf0c-5b70-40f8-9afb-a152ac9e41e6&r=yMJLF6E (타입: image)
# 리소스 차단: https://prebidlog.adop.cc/prebidlog/req?zid=4531bd75-1c28-483b-b239-edc197d7352e&type=req&bid=... (타입: image)
# 리소스 차단: https://static.criteo.net/images/pixel.gif?ch=1 (타입: image)
# 리소스 차단: https://static.criteo.net/images/pixel.gif?ch=2 (타입: image)
# 리소스 차단: https://partners.coupangcdn.com/widget/trending-keyword/default/f04e64595cdd2b3cf122a215a07c7459.png (타입: image)
# 리소스 차단: https://partners.coupangcdn.com/widget/trending-keyword/default/d179cb3bc170f0124ca5763f2db130fd.png (타입: image)
# 리소스 차단: https://partners.coupangcdn.com/widget/trending-keyword/default/c43923122bd48fa31d8206be394ed31c.png (타입: image)
# 리소스 차단: https://partners.coupangcdn.com/widget/trending-keyword/default/b1bdb28d1b1e95ef3fe00e61a4d77e23.png (타입: image)
# <!DOCTYPE html><html lang="ko"><head><script type="text/javascript" async="" src="https://linkback.contentsfeed.com/src/lb4iv.min.js?v=170111a" charset="utf-8"></script><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style>
#     <meta http-equiv="content-type" content="text/html; charset=utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=EDGE">
# <meta name="keywords" content="롤인벤,롤 전적검색,롤 기록실,e스포츠 뉴스,챔피언 공략,프로빌드,lol인벤,리그오브레전드,league of legends,롤,lol,롤공략">
# <meta name="description" content="롤인벤, 롤 전적검색, 롤 기록실, e스포츠 뉴스, 챔피언 공략, 프로빌드,lol인벤,리그오브레전드,카운터 픽,매치 히스토리, e스포츠 뉴스/기록실, 스킨 갤러리, 래더 랭킹">
# <meta name="naver-site-verification" content="3a508505e9bf09f6b8b7abe782e34f3cc895eb65">
# <meta name="inven-site" content="lol">
# <meta name="inven-sitename" content="리그오브레전드">
# <meta property="og:title" content="LoL 챔피언 공략 - 리그오브레전드 인벤">
# <meta property="og:type" content="website">
# <meta property="og:description" content="롤인벤, 롤 전적검색, 롤 기록실, e스포츠 뉴스, 챔피언 공략, 프로빌드,lol인벤,리그오브레전드,카운터 픽,매치 히스토리, e스포츠 뉴스/기록실, 스킨 갤러리, 래더 랭킹">
# <meta id="inven-verification" name="inven-verification" content="rI37UksjnjcIkJBMq+3N3w==">
# <title>LoL 챔피언 공략 - 리그오브레전드 인벤</title>
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/common/lib/style/dist/quicklink.css?v=97dad216bec0ed6e4c7b710b71da76d9a">
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/common/lib/style/ad.css?v=e6efe515f11e7365542f5ecbfad82f67a">
# <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PXPMBT3V"></script><script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/framework/jquery-1.7.2.min_new.js?v=20130113a"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/common_new.js?v=241119a"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/html_new.js"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/layer.js?v=20220518"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/xml_new.js?v=200117a"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/booster.js"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/browser.js?v=20200615"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/quicklink.js?v=7bda815c50c418facc1332a6df6cee99"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/zicf.js?v=aad916ab7d08e17d5efd96790f889ae0"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/dataninfo/lib/js/tooltip.js?v=20230310a"></script>
# <!--[if lte IE 9]><script src="https://www.inven.co.kr/common/lib/js/framework/html5shiv.js"></script><![endif]-->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PXPMBT3V');</script><link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/sitebuilder/lib/style/dist/commu_style.css?v=0658bea49cb8041acfbac9547f48d472a">
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/ibuilder/lib/style/dist/ibuilder_renew.css?v=fe35d2dcd777f4160327fe1d9f3020cda">
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/common/lib/style/event_popup.css?v=20210608aa">
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/lol/lib/style/dist/commu_style.css?v=62f2834d18571f2407f44d05b635d2cba">
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/common/lib/style/framework/swiper-bundle.8.4.6.min.css">
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/floatstatic.js?v=20210608a"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/location.js?v=20210608a"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/lol/lib/js/common.js?v=73b44d9ceef2eeb664a85e91f70806b3"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/framework/swiper-bundle.8.4.6.min.js"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/heatmap.js?v=0faeed9b76ff89488dd377693f92e0b9"></script>
# <script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/framework/jquery-ui-1.8.9.custom.min.js"></script>
# <link rel="stylesheet" type="text/css" href="https://www.inven.co.kr/lol/lib/style/dist/db_common.css?v=438a1e16691b9bafc1bdb634e6a06175a">
# <link rel="icon" href="https://static.inven.co.kr/image_2011/favicon_48x48.png" sizes="48x48">
# <link rel="icon" href="https://static.inven.co.kr/image_2011/favicon_192x192.png" sizes="192x192">
# <script type="text/javascript" async="" src="https://ssl.pstatic.net/melona/libs/gfp-nac-module/synchronizer.js"></script></head>
# <body class="styler-community has-leftmenu has-right pt-sub pt-dataninfo topsky"><div id="topskyAd" class="topskyad" style="background-color: rgb(0, 0, 0);"><div class="imgWrap" style="cursor: pointer;"><img src="//ads.inven.co.kr/ad/202411/1122_DNF_C_950x60.jpg" style="cursor: pointer;"></div><span style="cursor: pointer;">X</span></div>
#     <div id="topslideAd" class="topslideAd"></div>
# <script>if (document.body.className.indexOf('topsky') === -1) document.body.className += ' ' + 'topsky';</script>
# <script>INVEN.Ad.showTopSky('lol');</script><iframe id="comAdTopSky" name="comAdTopSky" width="0" height="0" frameborder="0" marginwidth="0" marginheight="0" topmargin="0" scrolling="no" src="https://zicf.inven.co.kr/RealMedia/ads/adstream_sx.ads/inven/lol@Top"></iframe><div class="topbar " id="comHeadlink">
# 	<div class="left mobile_area clearfix">
# 		<div><button class="app btn_pop" data-name="mobile" id="invenApp" onclick="$('#appList').toggle();">인벤 공식 앱</button></div>
# 				<div><a href="https://m.inven.co.kr/lol/" class="mobile">모바일 인벤</a></div>
# 			</div>
#
# 	<ul class="global_link clearfix">
#         		<li class="item"><a href="https://www.inven.co.kr/" class="link">웹진</a></li>
#         		<li class="item"><a href="https://party.inven.co.kr/" class="link">팟벤</a></li>
#         		<li class="item"><a href="https://it.inven.co.kr/" class="link">IT</a></li>
#         		<li class="item"><a href="https://esports.inven.co.kr/" class="link">e스포츠</a></li>
#         		<li class="item"><a href="https://pick.inven.co.kr/" class="link">사전예약</a></li>
#         		<li class="item"><a href="https://www.enchantenter.co.kr/" class="link">인챈트</a></li>
#         		<li class="item"><a href="https://imart.inven.co.kr/" class="link">아이마트</a></li>
#         	</ul>
#
# 	<script type="text/javascript" src="https://www.inven.co.kr/common/lib/js/outlogin.js"></script>
# <div class="right user_area clearfix">
#                     <div><button class="btn_signin" onclick="INVEN.Links.signIn();">회원가입</button></div>
#         <div><button class="btn_sign login" onclick="login();">로그인</button></div>
#                     <div><button class="btn_quicklink" onclick="INVEN.quickLink.toggle();">퀵링크</button></div>
# </div>
#
#  	<div class="pop_item pop_mobile" data-name="mobile" id="appList">
#
#         <div class="top_area">
#             <p class="row">
#                 <span class="name">인벤 모바일 앱 :</span>
#
#                     <a app-code="webzine" class="link">인벤 공식 앱</a>
#                             </p>
# 			<p class="row">
#                 <span class="name">인벤 게임 공략 :</span>
#                                         <a app-code="lostark" class="link">로스트아크</a>
#                                         <a app-code="lineagem" class="link">리니지M</a>
#                             </p>
#         </div>
#
#
#
# 		<div class="bottom_area clearfix" id="webzine">
# 			<img src="https://upload3.inven.co.kr/upload/2023/08/18/bbs/i8268349154.png" alt="" class="img_app">
# 			<div class="text">
# 				<p class="name" style="font-weight: bold; letter-spacing: -1px;"><strong>인벤 공식 앱</strong></p>
# 				<p class="value" style="font-weight: normal; letter-spacing: normal; color: #808080;">댓글 알람 기능 장착! 최신 게임뉴스를 한 눈에 보자</p>
# 			</div>
# 			<div class="btn_area">
#                  <a href="https://play.google.com/store/apps/details?id=kr.co.invenapp" class="link"><img src="//static.inven.co.kr/image_2011/cafe/common/btn_and01.png" alt="" class="img"></a>                <a href="https://itunes.apple.com/kr/app/inben-inven/id997288621?mt=8" class="link"><img src="//static.inven.co.kr/image_2011/cafe/common/btn_ios01.png" alt="" class="img"></a>			</div>
# 			<img src="https://upload2.inven.co.kr/upload/2017/06/29/bbs/i16069371144.jpg" alt="" class="img_qr">
#         </div>
#
# 		<div class="bottom_area clearfix hidden" id="lostark">
# 			<img src="https://upload2.inven.co.kr/upload/2019/03/07/bbs/i13588389197.jpg" alt="" class="img_app">
# 			<div class="text">
# 				<p class="name" style="font-weight: bold; letter-spacing: -1px;"><strong>로스트아크</strong></p>
# 				<p class="value" style="color: #808080;">캘린더 섬, 보스, 카오스게이트 알람! 꿀팁도 와르르</p>
# 			</div>
# 			<div class="btn_area">
#                  <a href="https://play.google.com/store/apps/details?id=kr.co.inven.android.lostark" class="link"><img src="//static.inven.co.kr/image_2011/cafe/common/btn_and01.png" alt="" class="img"></a>                			</div>
# 			<img src="https://upload2.inven.co.kr/upload/2019/03/07/bbs/i14021823717.jpg" alt="" class="img_qr">
#         </div>
#
# 		<div class="bottom_area clearfix hidden" id="lineagem">
# 			<img src="https://upload2.inven.co.kr/upload/2017/07/11/bbs/i15602285282.jpg" alt="" class="img_app">
# 			<div class="text">
# 				<p class="name" style="font-weight: bold; letter-spacing: -1px;"><strong>리니지M</strong></p>
# 				<p class="value" style="color: #808080;">리니지M 플레이하며 인벤 꿀팁까지 실시간으로 확인가능</p>
# 			</div>
# 			<div class="btn_area">
#                  <a href="https://play.google.com/store/apps/details?id=kr.co.inven.lineagem&amp;hl=ko" class="link"><img src="//static.inven.co.kr/image_2011/cafe/common/btn_and01.png" alt="" class="img"></a>                			</div>
# 			<img src="https://upload2.inven.co.kr/upload/2017/06/29/bbs/i14060662332.jpg" alt="" class="img_qr">
#         </div>
#
# 	</div>
#
# 	<script type="text/javascript">
# 		$(document).ready(function(e){
# 			$('#appList .top_area a').click(function(e){
# 				appcode = this.getAttribute('app-code');
# 				$('#appList .bottom_area').addClass('hidden');
# 				$('#appList .bottom_area#'+appcode).removeClass('hidden');
# 			});
# 		});
# 	</script></div>    <div id="lolBody" style="background: url('https://upload3.inven.co.kr/upload/2024/06/18/bbs/i1527859972.jpg') no-repeat top center;" class="bg-min-width">
#                 <div class="commu-wrap">
# 			<section class="commu-content ad-layout">
#                                 <header>
#                                         <h1 class="has-logo-image">
#                         <a href="https://lol.inven.co.kr/">
#                                                         <img src="https://upload3.inven.co.kr/upload/2023/04/04/bbs/i8206687393.png" alt="리그오브레전드 인벤">
#                                                     </a>
#                     </h1>
#                                         		           <style>body.styler-webzine.has-leftmenu .commu-content>article>.sh-wrap {padding-left:200px;}</style>
# 		           <div class="sh-wrap" style="float:right;">
# 			           			                    <div class="ad-header" style="background-color: rgb(255, 255, 255);">
# 				                    <script type="text/javascript">INVEN.Ad.showTop800('lol','ad-header');</script><iframe id="comAdTopBanner" name="comAdTopBanner" width="800" height="144" frameborder="0" marginwidth="0" marginheight="0" topmargin="0" scrolling="no" src="https://zicf.inven.co.kr/RealMedia/ads/adstream_sx.ads/inven/lol@x60?ipos=comAdTopBanner&amp;ibt=ad-header"></iframe>
# 			                    </div>
# 			            		           </div>
#                                     </header>
#                 <nav id="commu-nav">
#         <ul>
#                 <li class="system">
#                             <a href="https://lol.inven.co.kr/" target="_self">
#                                                             <span class="text">홈</span>
#                 </a>
#                                     </li>
#                 <li class="gnb-record">
#                             <a href="https://lol.inven.co.kr/dataninfo/match/teamList.php" target="_self">
#                                                             <span class="text">기록실</span>
#                 </a>
#                                 <ol class="hidden">
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/match/teamList.php">LoL 기록실 - 경기기록</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/match/playerList.php">LoL 기록실 - 선수기록</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/match/teamTotal.php">LoL 기록실 - 팀 통산</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/match/playerTotal.php">LoL 기록실 - 선수 통산</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/match/champTotal.php">LoL 기록실 - 챔피언 픽/밴</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/ladder/">LoL 기록실 - 래더 랭킹</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/proteam/proteam_gate.php">LoL 프로팀 정보</a></li>
#                                     </ol>
#                                     </li>
#                 <li class="system">
#                             <a href="https://lol.inven.co.kr/dataninfo/skin/" target="_self">
#                                                             <span class="text">스킨갤러리</span>
#                 </a>
#                                     </li>
#                 <li class="system">
#                             <a href="https://lol.inven.co.kr/dataninfo/champion/" target="_self">
#                                                             <span class="text">챔피언</span>
#                 </a>
#                                 <ol class="hidden">
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/champion/">LoL 챔피언 정보</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/champion/compare.php">챔피언 능력치 랭킹</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/rate/">실시간 챔피언 평가</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/counter/">카운터픽</a></li>
#                                     </ol>
#                                     </li>
#                 <li class="system">
#                             <a href="https://lol.inven.co.kr/dataninfo/champion/manualTool.php" target="_self">
#                                                             <span class="text">공략</span>
#                 </a>
#                                     </li>
#                 <li class="system">
#                             <a href="https://lol.inven.co.kr/dataninfo/mastery/" target="_self">
#                                                             <span class="text">LoL DB</span>
#                 </a>
#                                 <ol class="hidden">
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/mastery/">시즌14 룬 시뮬</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/item/list.php">시즌14 아이템 DB</a></li>
#                                         <li><a href="https://lol.inven.co.kr/dataninfo/summoner/">소환사 주문 DB</a></li>
#                                     </ol>
#                                     </li>
#             </ul>
#     </nav>
#
# <script>
# (function () {
#     $('nav#commu-nav > ul > li').on('mouseover', function () {
#         $(this).find('ol').removeClass('hidden');
#     }).on('mouseout', function () {
#         $(this).find('ol').addClass('hidden');
#     });
# })();
# </script>
#
#                 <article>
#                 <section class="commu-left">
#
# <div class="left-info">
#     <h2>
#         <a href="https://lol.inven.co.kr/" title="메인 페이지로 이동">
#             리그오브레전드 인벤        </a>
#     </h2>
#
#         <div class="log-out">
#         <p>로그인하고<br><span class="color">출석보상</span> 받으세요!</p>
#         <a href="#" onclick="login(); return false;" class="login-btn">
#             로그인        </a>
#
#                 <div>
#             <a href="https://member.inven.co.kr/user/pro/join" onclick="return onclickHref(event, window.INVEN.Links.signIn);">회원가입</a>
#             <a href="https://member.inven.co.kr/user/scorpio/find/info" onclick="return onclickHref(event, window.INVEN.Links.findIdPw);">ID/PW 찾기</a>
#         </div>
#             </div>
#     </div><div class="search" id="__left-search">
#     <form action="https://www.inven.co.kr/search" method="GET">
#         <input type="text" name="keyword" placeholder="LoL 인벤 통합검색">
#         <button type="submit">검색</button>
#     </form>
# </div>
#
# <script>
# (function () {
#     var parent = $('#__left-search');
# ...
#                                                     <li><a href="https://www.inven.co.kr/board/lol/4625/4007738"><span class="num">10</span><span class="txt">그리고 뭐 구마유시가 1년계약이라고 해서</span></a></li>
#                                                     </ul>
#                             <ul class="a_list ">
#                                 <li><a href="https://www.inven.co.kr/board/lol/2778/80918"><span class="num">1</span><span class="txt">빅토르 새 기본 일러스트</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80917"><span class="num">2</span><span class="txt">[개발 인사이드] 2025년 시즌 1 게임플레이 미리보기</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80916"><span class="num">3</span><span class="txt">[개발 인사이드] 2025년의 시즌</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80915"><span class="num">4</span><span class="txt">[개발 인사이드] 신속 대전 소개</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80913"><span class="num">5</span><span class="txt">[개발 인사이드] 2025년 시즌 1 랭크 게임 변경 사항</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80912"><span class="num">6</span><span class="txt">[S-2025] 신규 정글몬스터 "아타칸" 추가</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80911"><span class="num">7</span><span class="txt">빅토르 리워크 관련 공개된 정보</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80910"><span class="num">8</span><span class="txt">내가 좋아하는 일을 찾으세요 - T1 Faker</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80900"><span class="num">9</span><span class="txt">BRO Guger 합류</span></a></li>
#                                                     <li><a href="https://www.inven.co.kr/board/lol/2778/80894"><span class="num">10</span><span class="txt">26~2(요정트타, 기차오른, 장난감초가스)</span></a></li>
#                                                     </ul>
#                 </div>
# </div>
#
# <script>
# if (typeof tabEvent != 'function') {
# 	function tabEvent (tagName) {
# 		$('#hottestArticles.menuGroup ul.' + tagName + ' li').on("hover", function(){
# 			var tabIndex = $(this).index();
# 			$('#hottestArticles.menuGroup ul.' + tagName + ' li').removeClass('on').eq(tabIndex).addClass('on');
# 			$('#hottestArticles.menuGroup .' + tagName + ' .a_list').removeClass('on').eq(tabIndex).addClass('on');
# 		});
#     }
# }
#
# tabEvent('com_issue');
# </script>
# <div class="menuGroup ibs bg" id="broadcastSection" data-broadcast-domain="lol">
#     <h3>LoL LIVE 방송 </h3>
#
#         <div class="broadcaster-focus">
#         <a href="http://afreecatv.com/ilku5569" target="_blank" class="main_img https://liveimg.afreecatv.com/m/279032460?1732597622">
#                     <img src="https://liveimg.afreecatv.com/m/279032460?1732597622" style="width: 200px; height: 120px;">
#                     <p>Deft</p>
#         </a>
#     </div>
#
#     <div class="ibs_wrap">
#         <div class="broadcaster">
#
#             <a href="https://www.twitch.tv/corejj" target="_blank">
#                 <p class="stat act">LIVE</p>                                <p>Corejj <img src="https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon01.png"></p>
#             </a>
#
#             <a href="http://afreecatv.com/pig2704" target="_blank">
#                 <p class="stat act">LIVE</p>                                <p>Pray <img src="https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon02.png"></p>
#             </a>
#
#             <a href="https://chzzk.naver.com/8a59b34b46271960c1bf172bb0fac758" target="_blank">
#                 <p class="stat act">LIVE</p>                                <p>앰비션 <img src="https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon05.png"></p>
#             </a>
#
#             <a href="http://afreecatv.com/qjagus0000" target="_blank">
#                                 <p class="stat">OFF</p>                <p>Gorilla <img src="https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon02.png"></p>
#             </a>
#
#             <a href="https://www.twitch.tv/kingzonebdd" target="_blank">
#                                 <p class="stat">OFF</p>                <p>BDD <img src="https://static.inven.co.kr/image_2011/overwatch/module/afreecaBoard/live_icon01.png"></p>
#             </a>
#                     </div>
#         <div class="btn_wrap">
#             <button class="broadcast-refresh">새로고침</button>
#             <button class="broadcast-more">더보기</button>
#         </div>
#     </div>
# </div>
# <script>
# /**
#  * 우단 방송관련 스크립트
#  */
# (function ($) {
#     var domain = $('#broadcastSection').attr('data-broadcast-domain')
#         ,rightmenu = '#'+domain+'Right'
#         ,saveData = {}
#         ,$section = $(rightmenu+' #broadcastSection')
#         ,timer = null
#         ,channel = 1;
#
#     /* send data */
#     saveData.channel = channel;
#
#     $section.find('button.broadcast-refresh').on('click', function() {
#         $section.css('opacity', '.6');
#
#         if (timer) {
#             clearTimeout(timer);
#         }
#
#         timer = setTimeout(function () {
#             $.ajax({
#             url : '//www.inven.co.kr/common/module/broadcast/refresh.ajax.php',
#             type : 'POST',
#             data: saveData,
#             success: function(r) {
#                 if (typeof r == 'object' && r.status) {
#                     $section.find('.broadcaster-focus').html(r.contents.focus);
#                     $section.find('.broadcaster').html(r.contents.list);
#                 } else {
#                     window.alert('방송을 새로고침 할 수 없습니다.\n\n잠시 후 다시 시도해주세요.');
#                 }
#
#                 $section.css('opacity', '1.0');
#                 }
#             });
#         }, 250)
#     })
#
#     // 더보기 버튼
#     $section.find('button.broadcast-more').on('click', function() {
#         if (domain == 'webzine') {
#             location.href= '//www.inven.co.kr/webzine/stream/';
#         }else {
#             location.href = '//'+domain+'.inven.co.kr/dataninfo/stream/';
#         }
#     })
# })(jQuery)
# </script>
# <div class="menuGroup" id="wide_ad">
# 	<!-- /83673359,88413811/RS_inven_rightmiddle_250_250 -->
# 	<script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# 	<script>
# 	  var googletag = googletag || {};
# 	  googletag.cmd = googletag.cmd || [];
# 	</script>
# 	<div id="RS_inven_rightmiddle_250_250">
# 	  <script>
# 	    googletag.cmd.push(function ()
# 	{      googletag.defineSlot('/83673359,88413811/RS_inven_rightmiddle_250_250', [250, 250], 'RS_inven_rightmiddle_250_250').addService(googletag.pubads().set("page_url", "inven.co.kr"));
# 	      googletag.enableServices();
# 	      googletag.display('RS_inven_rightmiddle_250_250');
# 	    });
# 	  </script>
# 	</div>
# </div><div class="menuGroup" id="inven_reservation_box">
#     <h3>인벤 사전예약 <a href="https://pick.inven.co.kr/" target="_blank">더보기+</a></h3>
#     <div class="reser_wrap">
#                 <a href="https://pick.inven.co.kr/campaign/837/re" target="_blank">
#             <div class="thumb">
#                 <img src="https://upload3.inven.co.kr/upload/2024/10/24/data/i1182019280.jpg">
#             </div>
#             <div class="txt">
#                 <h4>리:메멘토 - 하얀 그림자</h4>
#                 <p>인벤 회원에게는 1000 이니, 100 베니 지급!</p>
#             </div>
#         </a>
#                 <a href="https://pick.inven.co.kr/campaign/831/EXILIUM" target="_blank">
#             <div class="thumb">
#                 <img src="https://upload3.inven.co.kr/upload/2024/10/07/data/i1419401431.png">
#             </div>
#             <div class="txt">
#                 <h4>소녀전선2: 망명</h4>
#                 <p>인벤 회원에게는 1000 이니, 100 베니 지급!</p>
#             </div>
#         </a>
#                 <a href="https://pick.inven.co.kr/campaign/824/JourneyofMonarch" target="_blank">
#             <div class="thumb">
#                 <img src="https://upload3.inven.co.kr/upload/2024/09/24/data/i1537177536.png">
#             </div>
#             <div class="txt">
#                 <h4>저니 오브 모나크</h4>
#                 <p>인벤 회원에게는 1000 이니, 100 베니 지급!</p>
#             </div>
#         </a>
#             </div>
# </div>
#     <div class="menuGroup imt_banner" id="modRightBrandpage">
#         <h3>브랜드 파트너 이벤트</h3>
#                 <div class="btnSet">
#             <a href="#" class="prev"></a>
#             <a href="#" class="next"></a>
#         </div>
#                 <div class="slider">
#             <ul class="panel">
#                                 <li class="panel1 on"><a href="https://www.inven.co.kr/board/steelseries/5676/134/?" class="img_area" target="_blank"><img src="https://upload3.inven.co.kr/upload/2024/11/19/bbs/i1411136240.jpg"></a></li>
#                                 <li class="panel1 "><a href="https://www.inven.co.kr/board/msi/4892/226/?" class="img_area" target="_blank"><img src="https://upload3.inven.co.kr/upload/2024/11/01/bbs/i1178476073.jpg"></a></li>
#                             </ul>
#         </div>
#     </div>
#
#     <script>
#     (function ($) {
#         var i = 0;
#         var len = $("#modRightBrandpage .panel>li").length;
#         var isAnimated = false;
#         var timer;
#
#         timer = setInterval(function(){
#             if(i==len-1){
#                 i=0;
#             }else{
#                 i++;
#             }
#             doNext(i);
#         },5000);
#
#         $("#modRightBrandpage .next").on("click",function(e){
#             e.preventDefault();
#             i = $("#modRightBrandpage .panel>li.on").index();
#
#             if(i==len-1){
#                 i=0;
#             }else{
#                 i++;
#             }
#             stop();
#             doNext(i);
#         });
#
#         $("#modRightBrandpage .prev").on("click",function(e){
#             e.preventDefault();
#             i = $("#modRightBrandpage .panel>li.on").index();
#
#             if(i==-len+1){
#                 i=0;
#             }else{
#                 i--;
#             }
#             stop();
#             doPrev(i);
#         });
#
#
#         function doNext(i){
#             if(!isAnimated){
#                 isAnimated=true;
#                 nextSlide(i);
#             }
#         }
#
#         function doPrev(i){
#             if(!isAnimated){
#                 isAnimated=true;
#                 prevSlide(i);
#             }
#         }
#
#         function nextSlide(i){
#             $("#modRightBrandpage .panel>li").not('.on').css("left","100%");
#             $("#modRightBrandpage .panel>li.on").stop().animate({"left":"-100%"},500,function(){
#                 $(this).css("left","100%").removeClass("on");
#             });
#             $("#modRightBrandpage .panel>li").eq(i).stop().animate({"left":"0%"},500,function(){
#                 $(this).addClass("on");
#                 isAnimated = false;
#             });
#         }
#
#         function prevSlide(i){
#             $("#modRightBrandpage .panel>li").not('.on').css("left","-100%");
#             $("#modRightBrandpage .panel>li.on").stop().animate({"left":"100%"},500,function(){
#                 $(this).css("left","-100%").removeClass("on");
#             });
#             $("#modRightBrandpage .panel>li").eq(i).stop().animate({"left":"0%"},500,function(){
#                 $(this).addClass("on");
#                 isAnimated = false;
#             });
#         }
#     })(jQuery)
#     </script>
#
# <div class="menuGroup imt_banner" id="cis">
#     <a href="https://www.inven.co.kr/board/webzine/2898" class="title"><h3>추천 코스프레 갤러리</h3></a>
#     <a href="https://www.inven.co.kr/board/webzine/2898/2334" class="img_area" target="_blank"><img src="https://upload3.inven.co.kr/upload/2024/08/26/bbs/i1138301350.jpg"></a>
#     <p class="cos_name">명조: 워더링 웨이브 에이크라운-넬리 금희</p>
# </div>
#             </div>
#         </div>
#     </section>
#
#     					    <section class="ad-right-side">
# 		    <script type="text/javascript" src="//tm.interworksmedia.co.kr/ads.js/E5BA7D37"></script><iframe frameborder="0" marginwidth="0" marginheight="0" scrolling="no" width="160" height="600" allowtransparency="true" src="//ds.interworksmedia.co.kr/RealMedia/ads/adstream_sx.ads/agency.inven_www.inven.co.kr_SECT_BA_160X600_ETC/agency@x62"></iframe>
# 		    <script>
# 			    if (typeof window.commuAdRightSideSticky == 'function') {
#                     commuAdRightSideSticky();
# 			    }
# 		    </script>
# 	    </section>
#
#
# </aside>	    </div> <!-- .commu-wrap -->
#         <div class="commu-tail">
#             <div id="comTailCoplyright">
# 	<h2 class="hidden">인포메이션</h2>
# 	<div class="infomationMenu">
# 		<ul class="infomationMenuList">
# 			<li class="menu menu1"><a href="https://www.inven.co.kr/webzine/zone/inventeam/?page=introduce" title="">회사소개</a></li>
# 			<li class="menu menu2"><a href="https://www.inven.co.kr/business/" title="">비즈니스</a></li>
# 			<li class="menu menu4"><a href="https://www.inven.co.kr/doc/service.php" title="">이용약관</a></li>
# 			<li class="menu menu5"><a href="https://www.inven.co.kr/doc/privacy.php" title=""><strong>개인정보처리방침</strong></a></li>
# 			<li class="menu menu6"><a href="https://www.inven.co.kr/doc/youthpolicy.php" title="">청소년보호정책</a></li>
# 			<li class="menu menu7"><a href="https://www.inven.co.kr/webzine/zone/inventeam/?page=location" title="">찾아오시는 길</a></li>
# 			<li class="menu menu8"><a href="https://www.inven.co.kr/board/powerbbs.php?come_idx=1292&amp;iskin=lol" title="">공지사항</a></li>
# 		</ul>
# 		<div class="infomationContent">
# 			<div class="infoText">
# 				<div class="textWrap">
# 					<p>명칭: <b>주식회사 인벤</b> | 등록번호: 경기 아51514 | <span class="mo-br"><br></span>등록연월일: 2009. 12. 14 | 제호: 인벤<span>(INVEN)</span></p>
# 					<p>발행인: 박규상 | 편집인: 강민우 | <span class="mo-br"><br></span>발행소: 경기도 성남시 분당구 구미로 9번길 3-4 한국빌딩 3층</p>
# 					<p>발행연월일: 2004 11. 11 | <span class="mo-br"><br></span>전화번호: 02 - 6393 - 7700 | E-mail: help@inven.co.kr</p>
# 					<p class="gap">인벤의 콘텐츠 및 기사는 저작권법의 보호를 받으므로, 무단 전재, 복사, 배포 등을 금합니다.</p>
# 					<p>Copyrightⓒ <span class="copyrightInven">Inven.</span> All rights reserved.</p>
# 				</div>
# 			</div>
# 			<div class="infoBanner">
# 				<div class="onc"><span>인터넷 신문 위원회 배너</span></div>
# 				<div class="isms">
# 					<div class="txt-box">
# 						<p>2023.08.26 ~ 2026.08.25</p>
# 						<p>인벤 온라인서비스 운영</p>
# 						<p>(웹진, 커뮤니티, 마켓인벤)</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="tail2TopBttn" onclick="document.getElementById('comHeadlink').scrollIntoView();" title="맨위로">▲</div>
# 	<div class="hidden">
# 		(주)인벤 사업자등록번호 : 120-86-74756<br>
# 		대표전화 : 02-6393-7700<br>
# 		FAX : 02-6393-7706<br>
# 		인벤의 콘텐츠 및 기사는 저작권법의 보호를 받으므로, 무단 전재·복사·배포 등을 금합니다.	<br>
# 		Copyright © Inven Communications. All rights reserved.
# 	</div>
# </div>
# 	<!-- Google tag (gtag.js) -->
# 	<script async="" src="https://www.googletagmanager.com/gtag/js?id=G-P0BBTC1DR3"></script>
# 	<script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
#
# 	  gtag('config', 'G-P0BBTC1DR3');
# 	</script>
# <script type="text/javascript">
# var linkback = linkback|| {};
# (function() {
# 	var d = document, scr = d.createElement('script'), pro = d.location.protocol,
# 	tar = d.getElementsByTagName('head')[0];
# 	scr.type = 'text/javascript';  scr.async = true;
# 	scr.src = ((pro === 'https:') ? 'https' : 'http') + '://linkback.contentsfeed.com/src/lb4iv.min.js?v=170111a';
# 	scr.charset='utf-8';
# 	if(!linkback.l){linkback.l=true; tar.insertBefore(scr, tar.firstChild);}
# })();
# </script>
#
# 	<script type="text/javascript" src="//wcs.naver.net/wcslog.js"></script>
# 	<script type="text/javascript">
# 	    if(!wcs_add) var wcs_add = {};
# 	    wcs_add["wa"] = "105811aa1e895d";
# 	    wcs_do();
# 	</script>
#
#
#         </div>
#     	</div> <!-- #siteBody -->
#
#
# <div id="comFloatAlert" style="display: none;"><ul class="textlist"></ul></div><div id="lolCommonLayer"></div></body></html>
